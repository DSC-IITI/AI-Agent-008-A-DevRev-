# %%
import pandas as pd
import numpy as np
import chromadb
from chromadb.config import Settings
from sentence_transformers import SentenceTransformer
from typing_extensions import Union, List, Tuple, Optional, Dict

from transformers import (
    AutoModelForQuestionAnswering,
    AutoTokenizer,
    pipeline,
    T5ForQuestionAnswering,
    BertForQuestionAnswering
)
import torch
import time
from dataclasses import dataclass

# %%
df = pd.read_csv('../data/train_data.csv')
df.head()
# Out:
#    Unnamed: 0    Theme                                          Paragraph  \
# 0           2  Beyoncé  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1           6  Beyoncé  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2           7  Beyoncé  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3           8  Beyoncé  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4           9  Beyoncé  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
#
#                                             Question  Answer_possible  \
# 0  When did Beyonce leave Destiny's Child and bec...             True
# 1      What album made her a worldwide known artist?             True
# 2             Who managed the Destiny's Child group?             True
# 3                     When did Beyoncé rise to fame?             True
# 4     What role did Beyoncé have in Destiny's Child?             True
#
#                Answer_text Answer_start
# 0                 ['2003']        [526]
# 1  ['Dangerously in Love']        [505]
# 2       ['Mathew Knowles']        [360]
# 3           ['late 1990s']        [276]
# 4          ['lead singer']        [290]

# %%
paragraphs = df['Paragraph'].values
print(len(paragraphs))
paragraphs[:5]
# Out:
# 75055
# array(['Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#        'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#        'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#        'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#        'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".'],
#       dtype=object)

# %%
paragraphs = np.unique(paragraphs)
print(len(paragraphs))
# Out:
# 15555

# %%
beyonce_paragraphs = [para for para in paragraphs if "Beyoncé Giselle" in para]
for para in beyonce_paragraphs:
    print(para)
# Out:
# Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, a Xerox sales manager. Beyoncé's name is a tribute to her mother's maiden name. Beyoncé's younger sister Solange is also a singer and a former member of Destiny's Child. Mathew is African-American, while Tina is of Louisiana Creole descent (with African, Native American, French, Cajun, and distant Irish and Spanish ancestry). Through her mother, Beyoncé is a descendant of Acadian leader Joseph Broussard. She was raised in a Methodist household.
# Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".

# %%
with open('context.txt', 'w', encoding='utf-8') as file:
    for paragraph in paragraphs:
        file.write(paragraph + '\n')

# %% [markdown]
# # Use ChromaDB to store embeddings

# %%
# Initialize ChromaDB client with the new architecture
client = chromadb.PersistentClient(
    path="./chroma_storage"  # Update this path as needed
)

# Create a collection (if it doesn't exist)
collection_name = "paragraph_collection"
try:
    collection = client.get_collection(collection_name)
except:
    collection = client.create_collection(collection_name)

# %%
print(type(paragraphs))
print(len(paragraphs))
# Out:
# <class 'numpy.ndarray'>
# 15555

# %%
def prepare_and_insert_data(
    paragraphs: Union[np.ndarray, List[str]], 
    collection: chromadb.Collection,
    batch_size: int = 500
) -> None:
    """
    Prepare and insert data into ChromaDB with proper handling of NumPy arrays
    
    Args:
        paragraphs: Array or list of text paragraphs
        collection: ChromaDB collection instance
        batch_size: Number of items to process in each batch
    """
    # Convert NumPy array to list if necessary
    if isinstance(paragraphs, np.ndarray):
        paragraphs = paragraphs.tolist()
    
    # Initialize the model
    model = SentenceTransformer('all-MiniLM-L6-v2')
    
    # Compute embeddings
    embeddings = model.encode(paragraphs).tolist()
    
    # Create document IDs and metadata
    doc_ids = [f"doc_{i}" for i in range(len(paragraphs))]
    metadatas = [{"index": i} for i in range(len(paragraphs))]
    
    # Verify lengths
    print(f"Verification counts:")
    print(f"Paragraphs: {len(paragraphs)}")
    print(f"Embeddings: {len(embeddings)}")
    print(f"IDs: {len(doc_ids)}")
    print(f"Metadata: {len(metadatas)}")
    
    # Add data to ChromaDB in batches
    for i in range(0, len(paragraphs), batch_size):
        batch_end = min(i + batch_size, len(paragraphs))
        collection.add(
            documents=paragraphs[i:batch_end],
            embeddings=embeddings[i:batch_end],
            metadatas=metadatas[i:batch_end],
            ids=doc_ids[i:batch_end]
        )
        if (i + batch_size) % 5000 == 0:
            print(f"Processed {i + batch_size} entries...")
    
    print(f"Successfully added {len(paragraphs)} paragraphs to ChromaDB!")

# %%
client = chromadb.PersistentClient(path="./chroma_storage")
collection = client.get_or_create_collection("paragraph_collection")
prepare_and_insert_data(paragraphs, collection)
# Out:
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_3
# Add of existing embedding ID: doc_4
# Add of existing embedding ID: doc_5
# Add of existing embedding ID: doc_6
# Add of existing embedding ID: doc_7
# Add of existing embedding ID: doc_8
# Add of existing embedding ID: doc_9
# Add of existing embedding ID: doc_10
# Add of existing embedding ID: doc_11
# Add of existing embedding ID: doc_12
# Add of existing embedding ID: doc_13
# Add of existing embedding ID: doc_14
# Add of existing embedding ID: doc_15
# Add of existing embedding ID: doc_16
# Add of existing embedding ID: doc_17
# Add of existing embedding ID: doc_18
# Add of existing embedding ID: doc_19
# Add of existing embedding ID: doc_20
# Add of existing embedding ID: doc_21
# Add of existing embedding ID: doc_22
# Add of existing embedding ID: doc_23
# Add of existing embedding ID: doc_24
# Add of existing embedding ID: doc_25
# Add of existing embedding ID: doc_26
# Add of existing embedding ID: doc_27
# Add of existing embedding ID: doc_28
# Add of existing embedding ID: doc_29
# Add of existing embedding ID: doc_30
# Add of existing embedding ID: doc_31
# Add of existing embedding ID: doc_32
# Add of existing embedding ID: doc_33
# Add of existing embedding ID: doc_34
# Add of existing embedding ID: doc_35
# Add of existing embedding ID: doc_36
# Add of existing embedding ID: doc_37
# Add of existing embedding ID: doc_38
# Add of existing embedding ID: doc_39
# Add of existing embedding ID: doc_40
# Add of existing embedding ID: doc_41
# Add of existing embedding ID: doc_42
# Add of existing embedding ID: doc_43
# Add of existing embedding ID: doc_44
# Add of existing embedding ID: doc_45
# Add of existing embedding ID: doc_46
# Add of existing embedding ID: doc_47
# Add of existing embedding ID: doc_48
# Add of existing embedding ID: doc_49
# Add of existing embedding ID: doc_50
# Add of existing embedding ID: doc_51
# Add of existing embedding ID: doc_52
# Add of existing embedding ID: doc_53
# Add of existing embedding ID: doc_54
# Add of existing embedding ID: doc_55
# Add of existing embedding ID: doc_56
# Add of existing embedding ID: doc_57
# Add of existing embedding ID: doc_58
# Add of existing embedding ID: doc_59
# Add of existing embedding ID: doc_60
# Add of existing embedding ID: doc_61
# Add of existing embedding ID: doc_62
# Add of existing embedding ID: doc_63
# Add of existing embedding ID: doc_64
# Add of existing embedding ID: doc_65
# Add of existing embedding ID: doc_66
# Add of existing embedding ID: doc_67
# Add of existing embedding ID: doc_68
# Add of existing embedding ID: doc_69
# Add of existing embedding ID: doc_70
# Add of existing embedding ID: doc_71
# Add of existing embedding ID: doc_72
# Add of existing embedding ID: doc_73
# Add of existing embedding ID: doc_74
# Add of existing embedding ID: doc_75
# Add of existing embedding ID: doc_76
# Add of existing embedding ID: doc_77
# Add of existing embedding ID: doc_78
# Add of existing embedding ID: doc_79
# Add of existing embedding ID: doc_80
# Add of existing embedding ID: doc_81
# Add of existing embedding ID: doc_82
# Add of existing embedding ID: doc_83
# Add of existing embedding ID: doc_84
# Add of existing embedding ID: doc_85
# Add of existing embedding ID: doc_86
# Add of existing embedding ID: doc_87
# Add of existing embedding ID: doc_88
# Add of existing embedding ID: doc_89
# Add of existing embedding ID: doc_90
# Add of existing embedding ID: doc_91
# Add of existing embedding ID: doc_92
# Add of existing embedding ID: doc_93
# Add of existing embedding ID: doc_94
# Add of existing embedding ID: doc_95
# Add of existing embedding ID: doc_96
# Add of existing embedding ID: doc_97
# Add of existing embedding ID: doc_98
# Add of existing embedding ID: doc_99
# Add of existing embedding ID: doc_100
# Add of existing embedding ID: doc_101
# Add of existing embedding ID: doc_102
# Add of existing embedding ID: doc_103
# Add of existing embedding ID: doc_104
# Add of existing embedding ID: doc_105
# Add of existing embedding ID: doc_106
# Add of existing embedding ID: doc_107
# Add of existing embedding ID: doc_108
# Add of existing embedding ID: doc_109
# Add of existing embedding ID: doc_110
# Add of existing embedding ID: doc_111
# Add of existing embedding ID: doc_112
# Add of existing embedding ID: doc_113
# Add of existing embedding ID: doc_114
# Add of existing embedding ID: doc_115
# Add of existing embedding ID: doc_116
# Add of existing embedding ID: doc_117
# Add of existing embedding ID: doc_118
# Add of existing embedding ID: doc_119
# Add of existing embedding ID: doc_120
# Add of existing embedding ID: doc_121
# Add of existing embedding ID: doc_122
# Add of existing embedding ID: doc_123
# Add of existing embedding ID: doc_124
# Add of existing embedding ID: doc_125
# Add of existing embedding ID: doc_126
# Add of existing embedding ID: doc_127
# Add of existing embedding ID: doc_128
# Add of existing embedding ID: doc_129
# Add of existing embedding ID: doc_130
# Add of existing embedding ID: doc_131
# Add of existing embedding ID: doc_132
# Add of existing embedding ID: doc_133
# Add of existing embedding ID: doc_134
# Add of existing embedding ID: doc_135
# Add of existing embedding ID: doc_136
# Add of existing embedding ID: doc_137
# Add of existing embedding ID: doc_138
# Add of existing embedding ID: doc_139
# Add of existing embedding ID: doc_140
# Add of existing embedding ID: doc_141
# Add of existing embedding ID: doc_142
# Add of existing embedding ID: doc_143
# Add of existing embedding ID: doc_144
# Add of existing embedding ID: doc_145
# Add of existing embedding ID: doc_146
# Add of existing embedding ID: doc_147
# Add of existing embedding ID: doc_148
# Add of existing embedding ID: doc_149
# Add of existing embedding ID: doc_150
# Add of existing embedding ID: doc_151
# Add of existing embedding ID: doc_152
# Add of existing embedding ID: doc_153
# Add of existing embedding ID: doc_154
# Add of existing embedding ID: doc_155
# Add of existing embedding ID: doc_156
# Add of existing embedding ID: doc_157
# Add of existing embedding ID: doc_158
# Add of existing embedding ID: doc_159
# Add of existing embedding ID: doc_160
# Add of existing embedding ID: doc_161
# Add of existing embedding ID: doc_162
# Add of existing embedding ID: doc_163
# Add of existing embedding ID: doc_164
# Add of existing embedding ID: doc_165
# Add of existing embedding ID: doc_166
# Add of existing embedding ID: doc_167
# Add of existing embedding ID: doc_168
# Add of existing embedding ID: doc_169
# Add of existing embedding ID: doc_170
# Add of existing embedding ID: doc_171
# Add of existing embedding ID: doc_172
# Add of existing embedding ID: doc_173
# Add of existing embedding ID: doc_174
# Add of existing embedding ID: doc_175
# Add of existing embedding ID: doc_176
# Add of existing embedding ID: doc_177
# Add of existing embedding ID: doc_178
# Add of existing embedding ID: doc_179
# Add of existing embedding ID: doc_180
# Add of existing embedding ID: doc_181
# Add of existing embedding ID: doc_182
# Add of existing embedding ID: doc_183
# Add of existing embedding ID: doc_184
# Add of existing embedding ID: doc_185
# Add of existing embedding ID: doc_186
# Add of existing embedding ID: doc_187
# Add of existing embedding ID: doc_188
# Add of existing embedding ID: doc_189
# Add of existing embedding ID: doc_190
# Add of existing embedding ID: doc_191
# Add of existing embedding ID: doc_192
# Add of existing embedding ID: doc_193
# Add of existing embedding ID: doc_194
# Add of existing embedding ID: doc_195
# Add of existing embedding ID: doc_196
# Add of existing embedding ID: doc_197
# Add of existing embedding ID: doc_198
# Add of existing embedding ID: doc_199
# Add of existing embedding ID: doc_200
# Add of existing embedding ID: doc_201
# Add of existing embedding ID: doc_202
# Add of existing embedding ID: doc_203
# Add of existing embedding ID: doc_204
# Add of existing embedding ID: doc_205
# Add of existing embedding ID: doc_206
# Add of existing embedding ID: doc_207
# Add of existing embedding ID: doc_208
# Add of existing embedding ID: doc_209
# Add of existing embedding ID: doc_210
# Add of existing embedding ID: doc_211
# Add of existing embedding ID: doc_212
# Add of existing embedding ID: doc_213
# Add of existing embedding ID: doc_214
# Add of existing embedding ID: doc_215
# Add of existing embedding ID: doc_216
# Add of existing embedding ID: doc_217
# Add of existing embedding ID: doc_218
# Add of existing embedding ID: doc_219
# Add of existing embedding ID: doc_220
# Add of existing embedding ID: doc_221
# Add of existing embedding ID: doc_222
# Add of existing embedding ID: doc_223
# Add of existing embedding ID: doc_224
# Add of existing embedding ID: doc_225
# Add of existing embedding ID: doc_226
# Add of existing embedding ID: doc_227
# Add of existing embedding ID: doc_228
# Add of existing embedding ID: doc_229
# Add of existing embedding ID: doc_230
# Add of existing embedding ID: doc_231
# Add of existing embedding ID: doc_232
# Add of existing embedding ID: doc_233
# Add of existing embedding ID: doc_234
# Add of existing embedding ID: doc_235
# Add of existing embedding ID: doc_236
# Add of existing embedding ID: doc_237
# Add of existing embedding ID: doc_238
# Add of existing embedding ID: doc_239
# Add of existing embedding ID: doc_240
# Add of existing embedding ID: doc_241
# Add of existing embedding ID: doc_242
# Add of existing embedding ID: doc_243
# Add of existing embedding ID: doc_244
# Add of existing embedding ID: doc_245
# Add of existing embedding ID: doc_246
# Add of existing embedding ID: doc_247
# Add of existing embedding ID: doc_248
# Add of existing embedding ID: doc_249
# Add of existing embedding ID: doc_250
# Add of existing embedding ID: doc_251
# Add of existing embedding ID: doc_252
# Add of existing embedding ID: doc_253
# Add of existing embedding ID: doc_254
# Add of existing embedding ID: doc_255
# Add of existing embedding ID: doc_256
# Add of existing embedding ID: doc_257
# Add of existing embedding ID: doc_258
# Add of existing embedding ID: doc_259
# Add of existing embedding ID: doc_260
# Add of existing embedding ID: doc_261
# Add of existing embedding ID: doc_262
# Add of existing embedding ID: doc_263
# Add of existing embedding ID: doc_264
# Add of existing embedding ID: doc_265
# Add of existing embedding ID: doc_266
# Add of existing embedding ID: doc_267
# Add of existing embedding ID: doc_268
# Add of existing embedding ID: doc_269
# Add of existing embedding ID: doc_270
# Add of existing embedding ID: doc_271
# Add of existing embedding ID: doc_272
# Add of existing embedding ID: doc_273
# Add of existing embedding ID: doc_274
# Add of existing embedding ID: doc_275
# Add of existing embedding ID: doc_276
# Add of existing embedding ID: doc_277
# Add of existing embedding ID: doc_278
# Add of existing embedding ID: doc_279
# Add of existing embedding ID: doc_280
# Add of existing embedding ID: doc_281
# Add of existing embedding ID: doc_282
# Add of existing embedding ID: doc_283
# Add of existing embedding ID: doc_284
# Add of existing embedding ID: doc_285
# Add of existing embedding ID: doc_286
# Add of existing embedding ID: doc_287
# Add of existing embedding ID: doc_288
# Add of existing embedding ID: doc_289
# Add of existing embedding ID: doc_290
# Add of existing embedding ID: doc_291
# Add of existing embedding ID: doc_292
# Add of existing embedding ID: doc_293
# Add of existing embedding ID: doc_294
# Add of existing embedding ID: doc_295
# Verification counts:
# Paragraphs: 15555
# Embeddings: 15555
# IDs: 15555
# Metadata: 15555
# Add of existing embedding ID: doc_296
# Add of existing embedding ID: doc_297
# Add of existing embedding ID: doc_298
# Add of existing embedding ID: doc_299
# Add of existing embedding ID: doc_300
# Add of existing embedding ID: doc_301
# Add of existing embedding ID: doc_302
# Add of existing embedding ID: doc_303
# Add of existing embedding ID: doc_304
# Add of existing embedding ID: doc_305
# Add of existing embedding ID: doc_306
# Add of existing embedding ID: doc_307
# Add of existing embedding ID: doc_308
# Add of existing embedding ID: doc_309
# Add of existing embedding ID: doc_310
# Add of existing embedding ID: doc_311
# Add of existing embedding ID: doc_312
# Add of existing embedding ID: doc_313
# Add of existing embedding ID: doc_314
# Add of existing embedding ID: doc_315
# Add of existing embedding ID: doc_316
# Add of existing embedding ID: doc_317
# Add of existing embedding ID: doc_318
# Add of existing embedding ID: doc_319
# Add of existing embedding ID: doc_320
# Add of existing embedding ID: doc_321
# Add of existing embedding ID: doc_322
# Add of existing embedding ID: doc_323
# Add of existing embedding ID: doc_324
# Add of existing embedding ID: doc_325
# Add of existing embedding ID: doc_326
# Add of existing embedding ID: doc_327
# Add of existing embedding ID: doc_328
# Add of existing embedding ID: doc_329
# Add of existing embedding ID: doc_330
# Add of existing embedding ID: doc_331
# Add of existing embedding ID: doc_332
# Add of existing embedding ID: doc_333
# Add of existing embedding ID: doc_334
# Add of existing embedding ID: doc_335
# Add of existing embedding ID: doc_336
# Add of existing embedding ID: doc_337
# Add of existing embedding ID: doc_338
# Add of existing embedding ID: doc_339
# Add of existing embedding ID: doc_340
# Add of existing embedding ID: doc_341
# Add of existing embedding ID: doc_342
# Add of existing embedding ID: doc_343
# Add of existing embedding ID: doc_344
# Add of existing embedding ID: doc_345
# Add of existing embedding ID: doc_346
# Add of existing embedding ID: doc_347
# Add of existing embedding ID: doc_348
# Add of existing embedding ID: doc_349
# Add of existing embedding ID: doc_350
# Add of existing embedding ID: doc_351
# Add of existing embedding ID: doc_352
# Add of existing embedding ID: doc_353
# Add of existing embedding ID: doc_354
# Add of existing embedding ID: doc_355
# Add of existing embedding ID: doc_356
# Add of existing embedding ID: doc_357
# Add of existing embedding ID: doc_358
# Add of existing embedding ID: doc_359
# Add of existing embedding ID: doc_360
# Add of existing embedding ID: doc_361
# Add of existing embedding ID: doc_362
# Add of existing embedding ID: doc_363
# Add of existing embedding ID: doc_364
# Add of existing embedding ID: doc_365
# Add of existing embedding ID: doc_366
# Add of existing embedding ID: doc_367
# Add of existing embedding ID: doc_368
# Add of existing embedding ID: doc_369
# Add of existing embedding ID: doc_370
# Add of existing embedding ID: doc_371
# Add of existing embedding ID: doc_372
# Add of existing embedding ID: doc_373
# Add of existing embedding ID: doc_374
# Add of existing embedding ID: doc_375
# Add of existing embedding ID: doc_376
# Add of existing embedding ID: doc_377
# Add of existing embedding ID: doc_378
# Add of existing embedding ID: doc_379
# Add of existing embedding ID: doc_380
# Add of existing embedding ID: doc_381
# Add of existing embedding ID: doc_382
# Add of existing embedding ID: doc_383
# Add of existing embedding ID: doc_384
# Add of existing embedding ID: doc_385
# Add of existing embedding ID: doc_386
# Add of existing embedding ID: doc_387
# Add of existing embedding ID: doc_388
# Add of existing embedding ID: doc_389
# Add of existing embedding ID: doc_390
# Add of existing embedding ID: doc_391
# Add of existing embedding ID: doc_392
# Add of existing embedding ID: doc_393
# Add of existing embedding ID: doc_394
# Add of existing embedding ID: doc_395
# Add of existing embedding ID: doc_396
# Add of existing embedding ID: doc_397
# Add of existing embedding ID: doc_398
# Add of existing embedding ID: doc_399
# Add of existing embedding ID: doc_400
# Add of existing embedding ID: doc_401
# Add of existing embedding ID: doc_402
# Add of existing embedding ID: doc_403
# Add of existing embedding ID: doc_404
# Add of existing embedding ID: doc_405
# Add of existing embedding ID: doc_406
# Add of existing embedding ID: doc_407
# Add of existing embedding ID: doc_408
# Add of existing embedding ID: doc_409
# Add of existing embedding ID: doc_410
# Add of existing embedding ID: doc_411
# Add of existing embedding ID: doc_412
# Add of existing embedding ID: doc_413
# Add of existing embedding ID: doc_414
# Add of existing embedding ID: doc_415
# Add of existing embedding ID: doc_416
# Add of existing embedding ID: doc_417
# Add of existing embedding ID: doc_418
# Add of existing embedding ID: doc_419
# Add of existing embedding ID: doc_420
# Add of existing embedding ID: doc_421
# Add of existing embedding ID: doc_422
# Add of existing embedding ID: doc_423
# Add of existing embedding ID: doc_424
# Add of existing embedding ID: doc_425
# Add of existing embedding ID: doc_426
# Add of existing embedding ID: doc_427
# Add of existing embedding ID: doc_428
# Add of existing embedding ID: doc_429
# Add of existing embedding ID: doc_430
# Add of existing embedding ID: doc_431
# Add of existing embedding ID: doc_432
# Add of existing embedding ID: doc_433
# Add of existing embedding ID: doc_434
# Add of existing embedding ID: doc_435
# Add of existing embedding ID: doc_436
# Add of existing embedding ID: doc_437
# Add of existing embedding ID: doc_438
# Add of existing embedding ID: doc_439
# Add of existing embedding ID: doc_440
# Add of existing embedding ID: doc_441
# Add of existing embedding ID: doc_442
# Add of existing embedding ID: doc_443
# Add of existing embedding ID: doc_444
# Add of existing embedding ID: doc_445
# Add of existing embedding ID: doc_446
# Add of existing embedding ID: doc_447
# Add of existing embedding ID: doc_448
# Add of existing embedding ID: doc_449
# Add of existing embedding ID: doc_450
# Add of existing embedding ID: doc_451
# Add of existing embedding ID: doc_452
# Add of existing embedding ID: doc_453
# Add of existing embedding ID: doc_454
# Add of existing embedding ID: doc_455
# Add of existing embedding ID: doc_456
# Add of existing embedding ID: doc_457
# Add of existing embedding ID: doc_458
# Add of existing embedding ID: doc_459
# Add of existing embedding ID: doc_460
# Add of existing embedding ID: doc_461
# Add of existing embedding ID: doc_462
# Add of existing embedding ID: doc_463
# Add of existing embedding ID: doc_464
# Add of existing embedding ID: doc_465
# Add of existing embedding ID: doc_466
# Add of existing embedding ID: doc_467
# Add of existing embedding ID: doc_468
# Add of existing embedding ID: doc_469
# Add of existing embedding ID: doc_470
# Add of existing embedding ID: doc_471
# Add of existing embedding ID: doc_472
# Add of existing embedding ID: doc_473
# Add of existing embedding ID: doc_474
# Add of existing embedding ID: doc_475
# Add of existing embedding ID: doc_476
# Add of existing embedding ID: doc_477
# Add of existing embedding ID: doc_478
# Add of existing embedding ID: doc_479
# Add of existing embedding ID: doc_480
# Add of existing embedding ID: doc_481
# Add of existing embedding ID: doc_482
# Add of existing embedding ID: doc_483
# Add of existing embedding ID: doc_484
# Add of existing embedding ID: doc_485
# Add of existing embedding ID: doc_486
# Add of existing embedding ID: doc_487
# Add of existing embedding ID: doc_488
# Add of existing embedding ID: doc_489
# Add of existing embedding ID: doc_490
# Add of existing embedding ID: doc_491
# Add of existing embedding ID: doc_492
# Add of existing embedding ID: doc_493
# Add of existing embedding ID: doc_494
# Add of existing embedding ID: doc_495
# Add of existing embedding ID: doc_496
# Add of existing embedding ID: doc_497
# Add of existing embedding ID: doc_498
# Add of existing embedding ID: doc_499
# Insert of existing embedding ID: doc_0
# Insert of existing embedding ID: doc_1
# Insert of existing embedding ID: doc_2
# Insert of existing embedding ID: doc_3
# Insert of existing embedding ID: doc_4
# Insert of existing embedding ID: doc_5
# Insert of existing embedding ID: doc_6
# Insert of existing embedding ID: doc_7
# Insert of existing embedding ID: doc_8
# Insert of existing embedding ID: doc_9
# Insert of existing embedding ID: doc_10
# Insert of existing embedding ID: doc_11
# Insert of existing embedding ID: doc_12
# Insert of existing embedding ID: doc_13
# Insert of existing embedding ID: doc_14
# Insert of existing embedding ID: doc_15
# Insert of existing embedding ID: doc_16
# Insert of existing embedding ID: doc_17
# Insert of existing embedding ID: doc_18
# Insert of existing embedding ID: doc_19
# Insert of existing embedding ID: doc_20
# Insert of existing embedding ID: doc_21
# Insert of existing embedding ID: doc_22
# Insert of existing embedding ID: doc_23
# Insert of existing embedding ID: doc_24
# Insert of existing embedding ID: doc_25
# Insert of existing embedding ID: doc_26
# Insert of existing embedding ID: doc_27
# Insert of existing embedding ID: doc_28
# Insert of existing embedding ID: doc_29
# Insert of existing embedding ID: doc_30
# Insert of existing embedding ID: doc_31
# Insert of existing embedding ID: doc_32
# Insert of existing embedding ID: doc_33
# Insert of existing embedding ID: doc_34
# Insert of existing embedding ID: doc_35
# Insert of existing embedding ID: doc_36
# Insert of existing embedding ID: doc_37
# Insert of existing embedding ID: doc_38
# Insert of existing embedding ID: doc_39
# Insert of existing embedding ID: doc_40
# Insert of existing embedding ID: doc_41
# Insert of existing embedding ID: doc_42
# Insert of existing embedding ID: doc_43
# Insert of existing embedding ID: doc_44
# Insert of existing embedding ID: doc_45
# Insert of existing embedding ID: doc_46
# Insert of existing embedding ID: doc_47
# Insert of existing embedding ID: doc_48
# Insert of existing embedding ID: doc_49
# Insert of existing embedding ID: doc_50
# Insert of existing embedding ID: doc_51
# Insert of existing embedding ID: doc_52
# Insert of existing embedding ID: doc_53
# Insert of existing embedding ID: doc_54
# Insert of existing embedding ID: doc_55
# Insert of existing embedding ID: doc_56
# Insert of existing embedding ID: doc_57
# Insert of existing embedding ID: doc_58
# Insert of existing embedding ID: doc_59
# Insert of existing embedding ID: doc_60
# Insert of existing embedding ID: doc_61
# Insert of existing embedding ID: doc_62
# Insert of existing embedding ID: doc_63
# Insert of existing embedding ID: doc_64
# Insert of existing embedding ID: doc_65
# Insert of existing embedding ID: doc_66
# Insert of existing embedding ID: doc_67
# Insert of existing embedding ID: doc_68
# Insert of existing embedding ID: doc_69
# Insert of existing embedding ID: doc_70
# Insert of existing embedding ID: doc_71
# Insert of existing embedding ID: doc_72
# Insert of existing embedding ID: doc_73
# Insert of existing embedding ID: doc_74
# Insert of existing embedding ID: doc_75
# Insert of existing embedding ID: doc_76
# Insert of existing embedding ID: doc_77
# Insert of existing embedding ID: doc_78
# Insert of existing embedding ID: doc_79
# Insert of existing embedding ID: doc_80
# Insert of existing embedding ID: doc_81
# Insert of existing embedding ID: doc_82
# Insert of existing embedding ID: doc_83
# Insert of existing embedding ID: doc_84
# Insert of existing embedding ID: doc_85
# Insert of existing embedding ID: doc_86
# Insert of existing embedding ID: doc_87
# Insert of existing embedding ID: doc_88
# Insert of existing embedding ID: doc_89
# Insert of existing embedding ID: doc_90
# Insert of existing embedding ID: doc_91
# Insert of existing embedding ID: doc_92
# Insert of existing embedding ID: doc_93
# Insert of existing embedding ID: doc_94
# Insert of existing embedding ID: doc_95
# Insert of existing embedding ID: doc_96
# Insert of existing embedding ID: doc_97
# Insert of existing embedding ID: doc_98
# Insert of existing embedding ID: doc_99
# Insert of existing embedding ID: doc_100
# Insert of existing embedding ID: doc_101
# Insert of existing embedding ID: doc_102
# Insert of existing embedding ID: doc_103
# Insert of existing embedding ID: doc_104
# Insert of existing embedding ID: doc_105
# Insert of existing embedding ID: doc_106
# Insert of existing embedding ID: doc_107
# Insert of existing embedding ID: doc_108
# Insert of existing embedding ID: doc_109
# Insert of existing embedding ID: doc_110
# Insert of existing embedding ID: doc_111
# Insert of existing embedding ID: doc_112
# Insert of existing embedding ID: doc_113
# Insert of existing embedding ID: doc_114
# Insert of existing embedding ID: doc_115
# Insert of existing embedding ID: doc_116
# Insert of existing embedding ID: doc_117
# Insert of existing embedding ID: doc_118
# Insert of existing embedding ID: doc_119
# Insert of existing embedding ID: doc_120
# Insert of existing embedding ID: doc_121
# Insert of existing embedding ID: doc_122
# Insert of existing embedding ID: doc_123
# Insert of existing embedding ID: doc_124
# Insert of existing embedding ID: doc_125
# Insert of existing embedding ID: doc_126
# Insert of existing embedding ID: doc_127
# Insert of existing embedding ID: doc_128
# Insert of existing embedding ID: doc_129
# Insert of existing embedding ID: doc_130
# Insert of existing embedding ID: doc_131
# Insert of existing embedding ID: doc_132
# Insert of existing embedding ID: doc_133
# Insert of existing embedding ID: doc_134
# Insert of existing embedding ID: doc_135
# Insert of existing embedding ID: doc_136
# Insert of existing embedding ID: doc_137
# Insert of existing embedding ID: doc_138
# Insert of existing embedding ID: doc_139
# Insert of existing embedding ID: doc_140
# Insert of existing embedding ID: doc_141
# Insert of existing embedding ID: doc_142
# Insert of existing embedding ID: doc_143
# Insert of existing embedding ID: doc_144
# Insert of existing embedding ID: doc_145
# Insert of existing embedding ID: doc_146
# Insert of existing embedding ID: doc_147
# Insert of existing embedding ID: doc_148
# Insert of existing embedding ID: doc_149
# Insert of existing embedding ID: doc_150
# Insert of existing embedding ID: doc_151
# Insert of existing embedding ID: doc_152
# Insert of existing embedding ID: doc_153
# Insert of existing embedding ID: doc_154
# Insert of existing embedding ID: doc_155
# Insert of existing embedding ID: doc_156
# Insert of existing embedding ID: doc_157
# Insert of existing embedding ID: doc_158
# Insert of existing embedding ID: doc_159
# Insert of existing embedding ID: doc_160
# Insert of existing embedding ID: doc_161
# Insert of existing embedding ID: doc_162
# Insert of existing embedding ID: doc_163
# Insert of existing embedding ID: doc_164
# Insert of existing embedding ID: doc_165
# Insert of existing embedding ID: doc_166
# Insert of existing embedding ID: doc_167
# Insert of existing embedding ID: doc_168
# Insert of existing embedding ID: doc_169
# Insert of existing embedding ID: doc_170
# Insert of existing embedding ID: doc_171
# Insert of existing embedding ID: doc_172
# Insert of existing embedding ID: doc_173
# Insert of existing embedding ID: doc_174
# Insert of existing embedding ID: doc_175
# Insert of existing embedding ID: doc_176
# Insert of existing embedding ID: doc_177
# Insert of existing embedding ID: doc_178
# Insert of existing embedding ID: doc_179
# Insert of existing embedding ID: doc_180
# Insert of existing embedding ID: doc_181
# Insert of existing embedding ID: doc_182
# Insert of existing embedding ID: doc_183
# Insert of existing embedding ID: doc_184
# Insert of existing embedding ID: doc_185
# Insert of existing embedding ID: doc_186
# Insert of existing embedding ID: doc_187
# Insert of existing embedding ID: doc_188
# Insert of existing embedding ID: doc_189
# Insert of existing embedding ID: doc_190
# Insert of existing embedding ID: doc_191
# Insert of existing embedding ID: doc_192
# Insert of existing embedding ID: doc_193
# Insert of existing embedding ID: doc_194
# Insert of existing embedding ID: doc_195
# Insert of existing embedding ID: doc_196
# Insert of existing embedding ID: doc_197
# Insert of existing embedding ID: doc_198
# Insert of existing embedding ID: doc_199
# Insert of existing embedding ID: doc_200
# Insert of existing embedding ID: doc_201
# Insert of existing embedding ID: doc_202
# Insert of existing embedding ID: doc_203
# Insert of existing embedding ID: doc_204
# Insert of existing embedding ID: doc_205
# Insert of existing embedding ID: doc_206
# Insert of existing embedding ID: doc_207
# Insert of existing embedding ID: doc_208
# Insert of existing embedding ID: doc_209
# Insert of existing embedding ID: doc_210
# Insert of existing embedding ID: doc_211
# Insert of existing embedding ID: doc_212
# Insert of existing embedding ID: doc_213
# Insert of existing embedding ID: doc_214
# Insert of existing embedding ID: doc_215
# Insert of existing embedding ID: doc_216
# Insert of existing embedding ID: doc_217
# Insert of existing embedding ID: doc_218
# Insert of existing embedding ID: doc_219
# Insert of existing embedding ID: doc_220
# Insert of existing embedding ID: doc_221
# Insert of existing embedding ID: doc_222
# Insert of existing embedding ID: doc_223
# Insert of existing embedding ID: doc_224
# Insert of existing embedding ID: doc_225
# Insert of existing embedding ID: doc_226
# Insert of existing embedding ID: doc_227
# Insert of existing embedding ID: doc_228
# Insert of existing embedding ID: doc_229
# Insert of existing embedding ID: doc_230
# Insert of existing embedding ID: doc_231
# Insert of existing embedding ID: doc_232
# Insert of existing embedding ID: doc_233
# Insert of existing embedding ID: doc_234
# Insert of existing embedding ID: doc_235
# Insert of existing embedding ID: doc_236
# Insert of existing embedding ID: doc_237
# Insert of existing embedding ID: doc_238
# Insert of existing embedding ID: doc_239
# Insert of existing embedding ID: doc_240
# Insert of existing embedding ID: doc_241
# Insert of existing embedding ID: doc_242
# Insert of existing embedding ID: doc_243
# Insert of existing embedding ID: doc_244
# Insert of existing embedding ID: doc_245
# Insert of existing embedding ID: doc_246
# Insert of existing embedding ID: doc_247
# Insert of existing embedding ID: doc_248
# Insert of existing embedding ID: doc_249
# Insert of existing embedding ID: doc_250
# Insert of existing embedding ID: doc_251
# Insert of existing embedding ID: doc_252
# Insert of existing embedding ID: doc_253
# Insert of existing embedding ID: doc_254
# Insert of existing embedding ID: doc_255
# Insert of existing embedding ID: doc_256
# Insert of existing embedding ID: doc_257
# Insert of existing embedding ID: doc_258
# Insert of existing embedding ID: doc_259
# Insert of existing embedding ID: doc_260
# Insert of existing embedding ID: doc_261
# Insert of existing embedding ID: doc_262
# Insert of existing embedding ID: doc_263
# Insert of existing embedding ID: doc_264
# Insert of existing embedding ID: doc_265
# Insert of existing embedding ID: doc_266
# Insert of existing embedding ID: doc_267
# Insert of existing embedding ID: doc_268
# Insert of existing embedding ID: doc_269
# Insert of existing embedding ID: doc_270
# Insert of existing embedding ID: doc_271
# Insert of existing embedding ID: doc_272
# Insert of existing embedding ID: doc_273
# Insert of existing embedding ID: doc_274
# Insert of existing embedding ID: doc_275
# Insert of existing embedding ID: doc_276
# Insert of existing embedding ID: doc_277
# Insert of existing embedding ID: doc_278
# Insert of existing embedding ID: doc_279
# Insert of existing embedding ID: doc_280
# Insert of existing embedding ID: doc_281
# Insert of existing embedding ID: doc_282
# Insert of existing embedding ID: doc_283
# Insert of existing embedding ID: doc_284
# Insert of existing embedding ID: doc_285
# Insert of existing embedding ID: doc_286
# Insert of existing embedding ID: doc_287
# Insert of existing embedding ID: doc_288
# Insert of existing embedding ID: doc_289
# Insert of existing embedding ID: doc_290
# Insert of existing embedding ID: doc_291
# Insert of existing embedding ID: doc_292
# Insert of existing embedding ID: doc_293
# Insert of existing embedding ID: doc_294
# Insert of existing embedding ID: doc_295
# Insert of existing embedding ID: doc_296
# Insert of existing embedding ID: doc_297
# Insert of existing embedding ID: doc_298
# Insert of existing embedding ID: doc_299
# Insert of existing embedding ID: doc_300
# Insert of existing embedding ID: doc_301
# Insert of existing embedding ID: doc_302
# Insert of existing embedding ID: doc_303
# Insert of existing embedding ID: doc_304
# Insert of existing embedding ID: doc_305
# Insert of existing embedding ID: doc_306
# Insert of existing embedding ID: doc_307
# Insert of existing embedding ID: doc_308
# Insert of existing embedding ID: doc_309
# Insert of existing embedding ID: doc_310
# Insert of existing embedding ID: doc_311
# Insert of existing embedding ID: doc_312
# Insert of existing embedding ID: doc_313
# Insert of existing embedding ID: doc_314
# Insert of existing embedding ID: doc_315
# Insert of existing embedding ID: doc_316
# Insert of existing embedding ID: doc_317
# Insert of existing embedding ID: doc_318
# Insert of existing embedding ID: doc_319
# Insert of existing embedding ID: doc_320
# Insert of existing embedding ID: doc_321
# Insert of existing embedding ID: doc_322
# Insert of existing embedding ID: doc_323
# Insert of existing embedding ID: doc_324
# Insert of existing embedding ID: doc_325
# Insert of existing embedding ID: doc_326
# Insert of existing embedding ID: doc_327
# Insert of existing embedding ID: doc_328
# Insert of existing embedding ID: doc_329
# Insert of existing embedding ID: doc_330
# Insert of existing embedding ID: doc_331
# Insert of existing embedding ID: doc_332
# Insert of existing embedding ID: doc_333
# Insert of existing embedding ID: doc_334
# Insert of existing embedding ID: doc_335
# Insert of existing embedding ID: doc_336
# Insert of existing embedding ID: doc_337
# Insert of existing embedding ID: doc_338
# Insert of existing embedding ID: doc_339
# Insert of existing embedding ID: doc_340
# Insert of existing embedding ID: doc_341
# Insert of existing embedding ID: doc_342
# Insert of existing embedding ID: doc_343
# Insert of existing embedding ID: doc_344
# Insert of existing embedding ID: doc_345
# Insert of existing embedding ID: doc_346
# Insert of existing embedding ID: doc_347
# Insert of existing embedding ID: doc_348
# Insert of existing embedding ID: doc_349
# Insert of existing embedding ID: doc_350
# Insert of existing embedding ID: doc_351
# Insert of existing embedding ID: doc_352
# Insert of existing embedding ID: doc_353
# Insert of existing embedding ID: doc_354
# Insert of existing embedding ID: doc_355
# Insert of existing embedding ID: doc_356
# Insert of existing embedding ID: doc_357
# Insert of existing embedding ID: doc_358
# Insert of existing embedding ID: doc_359
# Insert of existing embedding ID: doc_360
# Insert of existing embedding ID: doc_361
# Insert of existing embedding ID: doc_362
# Insert of existing embedding ID: doc_363
# Insert of existing embedding ID: doc_364
# Insert of existing embedding ID: doc_365
# Insert of existing embedding ID: doc_366
# Insert of existing embedding ID: doc_367
# Insert of existing embedding ID: doc_368
# Insert of existing embedding ID: doc_369
# Insert of existing embedding ID: doc_370
# Insert of existing embedding ID: doc_371
# Insert of existing embedding ID: doc_372
# Insert of existing embedding ID: doc_373
# Insert of existing embedding ID: doc_374
# Insert of existing embedding ID: doc_375
# Insert of existing embedding ID: doc_376
# Insert of existing embedding ID: doc_377
# Insert of existing embedding ID: doc_378
# Insert of existing embedding ID: doc_379
# Insert of existing embedding ID: doc_380
# Insert of existing embedding ID: doc_381
# Insert of existing embedding ID: doc_382
# Insert of existing embedding ID: doc_383
# Insert of existing embedding ID: doc_384
# Insert of existing embedding ID: doc_385
# Insert of existing embedding ID: doc_386
# Insert of existing embedding ID: doc_387
# Insert of existing embedding ID: doc_388
# Insert of existing embedding ID: doc_389
# Insert of existing embedding ID: doc_390
# Insert of existing embedding ID: doc_391
# Insert of existing embedding ID: doc_392
# Insert of existing embedding ID: doc_393
# Insert of existing embedding ID: doc_394
# Insert of existing embedding ID: doc_395
# Insert of existing embedding ID: doc_396
# Insert of existing embedding ID: doc_397
# Insert of existing embedding ID: doc_398
# Insert of existing embedding ID: doc_399
# Insert of existing embedding ID: doc_400
# Insert of existing embedding ID: doc_401
# Insert of existing embedding ID: doc_402
# Insert of existing embedding ID: doc_403
# Insert of existing embedding ID: doc_404
# Insert of existing embedding ID: doc_405
# Insert of existing embedding ID: doc_406
# Insert of existing embedding ID: doc_407
# Insert of existing embedding ID: doc_408
# Insert of existing embedding ID: doc_409
# Insert of existing embedding ID: doc_410
# Insert of existing embedding ID: doc_411
# Insert of existing embedding ID: doc_412
# Insert of existing embedding ID: doc_413
# Insert of existing embedding ID: doc_414
# Insert of existing embedding ID: doc_415
# Insert of existing embedding ID: doc_416
# Insert of existing embedding ID: doc_417
# Insert of existing embedding ID: doc_418
# Insert of existing embedding ID: doc_419
# Insert of existing embedding ID: doc_420
# Insert of existing embedding ID: doc_421
# Insert of existing embedding ID: doc_422
# Insert of existing embedding ID: doc_423
# Insert of existing embedding ID: doc_424
# Insert of existing embedding ID: doc_425
# Insert of existing embedding ID: doc_426
# Insert of existing embedding ID: doc_427
# Insert of existing embedding ID: doc_428
# Insert of existing embedding ID: doc_429
# Insert of existing embedding ID: doc_430
# Insert of existing embedding ID: doc_431
# Insert of existing embedding ID: doc_432
# Insert of existing embedding ID: doc_433
# Insert of existing embedding ID: doc_434
# Insert of existing embedding ID: doc_435
# Insert of existing embedding ID: doc_436
# Insert of existing embedding ID: doc_437
# Insert of existing embedding ID: doc_438
# Insert of existing embedding ID: doc_439
# Insert of existing embedding ID: doc_440
# Insert of existing embedding ID: doc_441
# Insert of existing embedding ID: doc_442
# Insert of existing embedding ID: doc_443
# Insert of existing embedding ID: doc_444
# Insert of existing embedding ID: doc_445
# Insert of existing embedding ID: doc_446
# Insert of existing embedding ID: doc_447
# Insert of existing embedding ID: doc_448
# Insert of existing embedding ID: doc_449
# Insert of existing embedding ID: doc_450
# Insert of existing embedding ID: doc_451
# Insert of existing embedding ID: doc_452
# Insert of existing embedding ID: doc_453
# Insert of existing embedding ID: doc_454
# Insert of existing embedding ID: doc_455
# Insert of existing embedding ID: doc_456
# Insert of existing embedding ID: doc_457
# Insert of existing embedding ID: doc_458
# Insert of existing embedding ID: doc_459
# Insert of existing embedding ID: doc_460
# Insert of existing embedding ID: doc_461
# Insert of existing embedding ID: doc_462
# Insert of existing embedding ID: doc_463
# Insert of existing embedding ID: doc_464
# Insert of existing embedding ID: doc_465
# Insert of existing embedding ID: doc_466
# Insert of existing embedding ID: doc_467
# Insert of existing embedding ID: doc_468
# Insert of existing embedding ID: doc_469
# Insert of existing embedding ID: doc_470
# Insert of existing embedding ID: doc_471
# Insert of existing embedding ID: doc_472
# Insert of existing embedding ID: doc_473
# Insert of existing embedding ID: doc_474
# Insert of existing embedding ID: doc_475
# Insert of existing embedding ID: doc_476
# Insert of existing embedding ID: doc_477
# Insert of existing embedding ID: doc_478
# Insert of existing embedding ID: doc_479
# Insert of existing embedding ID: doc_480
# Insert of existing embedding ID: doc_481
# Insert of existing embedding ID: doc_482
# Insert of existing embedding ID: doc_483
# Insert of existing embedding ID: doc_484
# Insert of existing embedding ID: doc_485
# Insert of existing embedding ID: doc_486
# Insert of existing embedding ID: doc_487
# Insert of existing embedding ID: doc_488
# Insert of existing embedding ID: doc_489
# Insert of existing embedding ID: doc_490
# Insert of existing embedding ID: doc_491
# Insert of existing embedding ID: doc_492
# Insert of existing embedding ID: doc_493
# Insert of existing embedding ID: doc_494
# Insert of existing embedding ID: doc_495
# Insert of existing embedding ID: doc_496
# Insert of existing embedding ID: doc_497
# Insert of existing embedding ID: doc_498
# Insert of existing embedding ID: doc_499
# Add of existing embedding ID: doc_500
# Add of existing embedding ID: doc_501
# Add of existing embedding ID: doc_502
# Add of existing embedding ID: doc_503
# Add of existing embedding ID: doc_504
# Add of existing embedding ID: doc_505
# Add of existing embedding ID: doc_506
# Add of existing embedding ID: doc_507
# Add of existing embedding ID: doc_508
# Add of existing embedding ID: doc_509
# Add of existing embedding ID: doc_510
# Add of existing embedding ID: doc_511
# Add of existing embedding ID: doc_512
# Add of existing embedding ID: doc_513
# Add of existing embedding ID: doc_514
# Add of existing embedding ID: doc_515
# Add of existing embedding ID: doc_516
# Add of existing embedding ID: doc_517
# Add of existing embedding ID: doc_518
# Add of existing embedding ID: doc_519
# Add of existing embedding ID: doc_520
# Add of existing embedding ID: doc_521
# Add of existing embedding ID: doc_522
# Add of existing embedding ID: doc_523
# Add of existing embedding ID: doc_524
# Add of existing embedding ID: doc_525
# Add of existing embedding ID: doc_526
# Add of existing embedding ID: doc_527
# Add of existing embedding ID: doc_528
# Add of existing embedding ID: doc_529
# Add of existing embedding ID: doc_530
# Add of existing embedding ID: doc_531
# Add of existing embedding ID: doc_532
# Add of existing embedding ID: doc_533
# Add of existing embedding ID: doc_534
# Add of existing embedding ID: doc_535
# Add of existing embedding ID: doc_536
# Add of existing embedding ID: doc_537
# Add of existing embedding ID: doc_538
# Add of existing embedding ID: doc_539
# Add of existing embedding ID: doc_540
# Add of existing embedding ID: doc_541
# Add of existing embedding ID: doc_542
# Add of existing embedding ID: doc_543
# Add of existing embedding ID: doc_544
# Add of existing embedding ID: doc_545
# Add of existing embedding ID: doc_546
# Add of existing embedding ID: doc_547
# Add of existing embedding ID: doc_548
# Add of existing embedding ID: doc_549
# Add of existing embedding ID: doc_550
# Add of existing embedding ID: doc_551
# Add of existing embedding ID: doc_552
# Add of existing embedding ID: doc_553
# Add of existing embedding ID: doc_554
# Add of existing embedding ID: doc_555
# Add of existing embedding ID: doc_556
# Add of existing embedding ID: doc_557
# Add of existing embedding ID: doc_558
# Add of existing embedding ID: doc_559
# Add of existing embedding ID: doc_560
# Add of existing embedding ID: doc_561
# Add of existing embedding ID: doc_562
# Add of existing embedding ID: doc_563
# Add of existing embedding ID: doc_564
# Add of existing embedding ID: doc_565
# Add of existing embedding ID: doc_566
# Add of existing embedding ID: doc_567
# Add of existing embedding ID: doc_568
# Add of existing embedding ID: doc_569
# Add of existing embedding ID: doc_570
# Add of existing embedding ID: doc_571
# Add of existing embedding ID: doc_572
# Add of existing embedding ID: doc_573
# Add of existing embedding ID: doc_574
# Add of existing embedding ID: doc_575
# Add of existing embedding ID: doc_576
# Add of existing embedding ID: doc_577
# Add of existing embedding ID: doc_578
# Add of existing embedding ID: doc_579
# Add of existing embedding ID: doc_580
# Add of existing embedding ID: doc_581
# Add of existing embedding ID: doc_582
# Add of existing embedding ID: doc_583
# Add of existing embedding ID: doc_584
# Add of existing embedding ID: doc_585
# Add of existing embedding ID: doc_586
# Add of existing embedding ID: doc_587
# Add of existing embedding ID: doc_588
# Add of existing embedding ID: doc_589
# Add of existing embedding ID: doc_590
# Add of existing embedding ID: doc_591
# Add of existing embedding ID: doc_592
# Add of existing embedding ID: doc_593
# Add of existing embedding ID: doc_594
# Add of existing embedding ID: doc_595
# Add of existing embedding ID: doc_596
# Add of existing embedding ID: doc_597
# Add of existing embedding ID: doc_598
# Add of existing embedding ID: doc_599
# Add of existing embedding ID: doc_600
# Add of existing embedding ID: doc_601
# Add of existing embedding ID: doc_602
# Add of existing embedding ID: doc_603
# Add of existing embedding ID: doc_604
# Add of existing embedding ID: doc_605
# Add of existing embedding ID: doc_606
# Add of existing embedding ID: doc_607
# Add of existing embedding ID: doc_608
# Add of existing embedding ID: doc_609
# Add of existing embedding ID: doc_610
# Add of existing embedding ID: doc_611
# Add of existing embedding ID: doc_612
# Add of existing embedding ID: doc_613
# Add of existing embedding ID: doc_614
# Add of existing embedding ID: doc_615
# Add of existing embedding ID: doc_616
# Add of existing embedding ID: doc_617
# Add of existing embedding ID: doc_618
# Add of existing embedding ID: doc_619
# Add of existing embedding ID: doc_620
# Add of existing embedding ID: doc_621
# Add of existing embedding ID: doc_622
# Add of existing embedding ID: doc_623
# Add of existing embedding ID: doc_624
# Add of existing embedding ID: doc_625
# Add of existing embedding ID: doc_626
# Add of existing embedding ID: doc_627
# Add of existing embedding ID: doc_628
# Add of existing embedding ID: doc_629
# Add of existing embedding ID: doc_630
# Add of existing embedding ID: doc_631
# Add of existing embedding ID: doc_632
# Add of existing embedding ID: doc_633
# Add of existing embedding ID: doc_634
# Add of existing embedding ID: doc_635
# Add of existing embedding ID: doc_636
# Add of existing embedding ID: doc_637
# Add of existing embedding ID: doc_638
# Add of existing embedding ID: doc_639
# Add of existing embedding ID: doc_640
# Add of existing embedding ID: doc_641
# Add of existing embedding ID: doc_642
# Add of existing embedding ID: doc_643
# Add of existing embedding ID: doc_644
# Add of existing embedding ID: doc_645
# Add of existing embedding ID: doc_646
# Add of existing embedding ID: doc_647
# Add of existing embedding ID: doc_648
# Add of existing embedding ID: doc_649
# Add of existing embedding ID: doc_650
# Add of existing embedding ID: doc_651
# Add of existing embedding ID: doc_652
# Add of existing embedding ID: doc_653
# Add of existing embedding ID: doc_654
# Add of existing embedding ID: doc_655
# Add of existing embedding ID: doc_656
# Add of existing embedding ID: doc_657
# Add of existing embedding ID: doc_658
# Add of existing embedding ID: doc_659
# Add of existing embedding ID: doc_660
# Add of existing embedding ID: doc_661
# Add of existing embedding ID: doc_662
# Add of existing embedding ID: doc_663
# Add of existing embedding ID: doc_664
# Add of existing embedding ID: doc_665
# Add of existing embedding ID: doc_666
# Add of existing embedding ID: doc_667
# Add of existing embedding ID: doc_668
# Add of existing embedding ID: doc_669
# Add of existing embedding ID: doc_670
# Add of existing embedding ID: doc_671
# Add of existing embedding ID: doc_672
# Add of existing embedding ID: doc_673
# Add of existing embedding ID: doc_674
# Add of existing embedding ID: doc_675
# Add of existing embedding ID: doc_676
# Add of existing embedding ID: doc_677
# Add of existing embedding ID: doc_678
# Add of existing embedding ID: doc_679
# Add of existing embedding ID: doc_680
# Add of existing embedding ID: doc_681
# Add of existing embedding ID: doc_682
# Add of existing embedding ID: doc_683
# Add of existing embedding ID: doc_684
# Add of existing embedding ID: doc_685
# Add of existing embedding ID: doc_686
# Add of existing embedding ID: doc_687
# Add of existing embedding ID: doc_688
# Add of existing embedding ID: doc_689
# Add of existing embedding ID: doc_690
# Add of existing embedding ID: doc_691
# Add of existing embedding ID: doc_692
# Add of existing embedding ID: doc_693
# Add of existing embedding ID: doc_694
# Add of existing embedding ID: doc_695
# Add of existing embedding ID: doc_696
# Add of existing embedding ID: doc_697
# Add of existing embedding ID: doc_698
# Add of existing embedding ID: doc_699
# Add of existing embedding ID: doc_700
# Add of existing embedding ID: doc_701
# Add of existing embedding ID: doc_702
# Add of existing embedding ID: doc_703
# Add of existing embedding ID: doc_704
# Add of existing embedding ID: doc_705
# Add of existing embedding ID: doc_706
# Add of existing embedding ID: doc_707
# Add of existing embedding ID: doc_708
# Add of existing embedding ID: doc_709
# Add of existing embedding ID: doc_710
# Add of existing embedding ID: doc_711
# Add of existing embedding ID: doc_712
# Add of existing embedding ID: doc_713
# Add of existing embedding ID: doc_714
# Add of existing embedding ID: doc_715
# Add of existing embedding ID: doc_716
# Add of existing embedding ID: doc_717
# Add of existing embedding ID: doc_718
# Add of existing embedding ID: doc_719
# Add of existing embedding ID: doc_720
# Add of existing embedding ID: doc_721
# Add of existing embedding ID: doc_722
# Add of existing embedding ID: doc_723
# Add of existing embedding ID: doc_724
# Add of existing embedding ID: doc_725
# Add of existing embedding ID: doc_726
# ...
# Insert of existing embedding ID: doc_15236
# Insert of existing embedding ID: doc_15237
# Insert of existing embedding ID: doc_15238
# Insert of existing embedding ID: doc_15239
# Insert of existing embedding ID: doc_15240
# Insert of existing embedding ID: doc_15241
# Insert of existing embedding ID: doc_15242
# Insert of existing embedding ID: doc_15243
# Insert of existing embedding ID: doc_15244
# Insert of existing embedding ID: doc_15245
# Insert of existing embedding ID: doc_15246
# Insert of existing embedding ID: doc_15247
# Insert of existing embedding ID: doc_15248
# Insert of existing embedding ID: doc_15249
# Insert of existing embedding ID: doc_15250
# Insert of existing embedding ID: doc_15251
# Insert of existing embedding ID: doc_15252
# Insert of existing embedding ID: doc_15253
# Insert of existing embedding ID: doc_15254
# Insert of existing embedding ID: doc_15255
# Insert of existing embedding ID: doc_15256
# Insert of existing embedding ID: doc_15257
# Insert of existing embedding ID: doc_15258
# Insert of existing embedding ID: doc_15259
# Insert of existing embedding ID: doc_15260
# Insert of existing embedding ID: doc_15261
# Insert of existing embedding ID: doc_15262
# Insert of existing embedding ID: doc_15263
# Insert of existing embedding ID: doc_15264
# Insert of existing embedding ID: doc_15265
# Insert of existing embedding ID: doc_15266
# Insert of existing embedding ID: doc_15267
# Insert of existing embedding ID: doc_15268
# Insert of existing embedding ID: doc_15269
# Insert of existing embedding ID: doc_15270
# Insert of existing embedding ID: doc_15271
# Insert of existing embedding ID: doc_15272
# Insert of existing embedding ID: doc_15273
# Insert of existing embedding ID: doc_15274
# Insert of existing embedding ID: doc_15275
# Insert of existing embedding ID: doc_15276
# Insert of existing embedding ID: doc_15277
# Insert of existing embedding ID: doc_15278
# Insert of existing embedding ID: doc_15279
# Insert of existing embedding ID: doc_15280
# Insert of existing embedding ID: doc_15281
# Insert of existing embedding ID: doc_15282
# Insert of existing embedding ID: doc_15283
# Insert of existing embedding ID: doc_15284
# Insert of existing embedding ID: doc_15285
# Insert of existing embedding ID: doc_15286
# Insert of existing embedding ID: doc_15287
# Insert of existing embedding ID: doc_15288
# Insert of existing embedding ID: doc_15289
# Insert of existing embedding ID: doc_15290
# Insert of existing embedding ID: doc_15291
# Insert of existing embedding ID: doc_15292
# Insert of existing embedding ID: doc_15293
# Insert of existing embedding ID: doc_15294
# Insert of existing embedding ID: doc_15295
# Insert of existing embedding ID: doc_15296
# Insert of existing embedding ID: doc_15297
# Insert of existing embedding ID: doc_15298
# Insert of existing embedding ID: doc_15299
# Insert of existing embedding ID: doc_15300
# Insert of existing embedding ID: doc_15301
# Insert of existing embedding ID: doc_15302
# Insert of existing embedding ID: doc_15303
# Insert of existing embedding ID: doc_15304
# Insert of existing embedding ID: doc_15305
# Insert of existing embedding ID: doc_15306
# Insert of existing embedding ID: doc_15307
# Insert of existing embedding ID: doc_15308
# Insert of existing embedding ID: doc_15309
# Insert of existing embedding ID: doc_15310
# Insert of existing embedding ID: doc_15311
# Insert of existing embedding ID: doc_15312
# Insert of existing embedding ID: doc_15313
# Insert of existing embedding ID: doc_15314
# Insert of existing embedding ID: doc_15315
# Insert of existing embedding ID: doc_15316
# Insert of existing embedding ID: doc_15317
# Insert of existing embedding ID: doc_15318
# Insert of existing embedding ID: doc_15319
# Insert of existing embedding ID: doc_15320
# Insert of existing embedding ID: doc_15321
# Insert of existing embedding ID: doc_15322
# Insert of existing embedding ID: doc_15323
# Insert of existing embedding ID: doc_15324
# Insert of existing embedding ID: doc_15325
# Insert of existing embedding ID: doc_15326
# Insert of existing embedding ID: doc_15327
# Insert of existing embedding ID: doc_15328
# Insert of existing embedding ID: doc_15329
# Insert of existing embedding ID: doc_15330
# Insert of existing embedding ID: doc_15331
# Insert of existing embedding ID: doc_15332
# Insert of existing embedding ID: doc_15333
# Insert of existing embedding ID: doc_15334
# Insert of existing embedding ID: doc_15335
# Insert of existing embedding ID: doc_15336
# Insert of existing embedding ID: doc_15337
# Insert of existing embedding ID: doc_15338
# Insert of existing embedding ID: doc_15339
# Insert of existing embedding ID: doc_15340
# Insert of existing embedding ID: doc_15341
# Insert of existing embedding ID: doc_15342
# Insert of existing embedding ID: doc_15343
# Insert of existing embedding ID: doc_15344
# Insert of existing embedding ID: doc_15345
# Insert of existing embedding ID: doc_15346
# Insert of existing embedding ID: doc_15347
# Insert of existing embedding ID: doc_15348
# Insert of existing embedding ID: doc_15349
# Insert of existing embedding ID: doc_15350
# Insert of existing embedding ID: doc_15351
# Insert of existing embedding ID: doc_15352
# Insert of existing embedding ID: doc_15353
# Insert of existing embedding ID: doc_15354
# Insert of existing embedding ID: doc_15355
# Insert of existing embedding ID: doc_15356
# Insert of existing embedding ID: doc_15357
# Insert of existing embedding ID: doc_15358
# Insert of existing embedding ID: doc_15359
# Insert of existing embedding ID: doc_15360
# Insert of existing embedding ID: doc_15361
# Insert of existing embedding ID: doc_15362
# Insert of existing embedding ID: doc_15363
# Insert of existing embedding ID: doc_15364
# Insert of existing embedding ID: doc_15365
# Insert of existing embedding ID: doc_15366
# Insert of existing embedding ID: doc_15367
# Insert of existing embedding ID: doc_15368
# Insert of existing embedding ID: doc_15369
# Insert of existing embedding ID: doc_15370
# Insert of existing embedding ID: doc_15371
# Insert of existing embedding ID: doc_15372
# Insert of existing embedding ID: doc_15373
# Insert of existing embedding ID: doc_15374
# Insert of existing embedding ID: doc_15375
# Insert of existing embedding ID: doc_15376
# Insert of existing embedding ID: doc_15377
# Insert of existing embedding ID: doc_15378
# Insert of existing embedding ID: doc_15379
# Insert of existing embedding ID: doc_15380
# Insert of existing embedding ID: doc_15381
# Insert of existing embedding ID: doc_15382
# Insert of existing embedding ID: doc_15383
# Insert of existing embedding ID: doc_15384
# Insert of existing embedding ID: doc_15385
# Insert of existing embedding ID: doc_15386
# Insert of existing embedding ID: doc_15387
# Insert of existing embedding ID: doc_15388
# Insert of existing embedding ID: doc_15389
# Insert of existing embedding ID: doc_15390
# Insert of existing embedding ID: doc_15391
# Insert of existing embedding ID: doc_15392
# Insert of existing embedding ID: doc_15393
# Insert of existing embedding ID: doc_15394
# Insert of existing embedding ID: doc_15395
# Insert of existing embedding ID: doc_15396
# Insert of existing embedding ID: doc_15397
# Insert of existing embedding ID: doc_15398
# Insert of existing embedding ID: doc_15399
# Insert of existing embedding ID: doc_15400
# Insert of existing embedding ID: doc_15401
# Insert of existing embedding ID: doc_15402
# Insert of existing embedding ID: doc_15403
# Insert of existing embedding ID: doc_15404
# Insert of existing embedding ID: doc_15405
# Insert of existing embedding ID: doc_15406
# Insert of existing embedding ID: doc_15407
# Insert of existing embedding ID: doc_15408
# Insert of existing embedding ID: doc_15409
# Insert of existing embedding ID: doc_15410
# Insert of existing embedding ID: doc_15411
# Insert of existing embedding ID: doc_15412
# Insert of existing embedding ID: doc_15413
# Insert of existing embedding ID: doc_15414
# Insert of existing embedding ID: doc_15415
# Insert of existing embedding ID: doc_15416
# Insert of existing embedding ID: doc_15417
# Insert of existing embedding ID: doc_15418
# Insert of existing embedding ID: doc_15419
# Insert of existing embedding ID: doc_15420
# Insert of existing embedding ID: doc_15421
# Insert of existing embedding ID: doc_15422
# Insert of existing embedding ID: doc_15423
# Insert of existing embedding ID: doc_15424
# Insert of existing embedding ID: doc_15425
# Insert of existing embedding ID: doc_15426
# Insert of existing embedding ID: doc_15427
# Insert of existing embedding ID: doc_15428
# Insert of existing embedding ID: doc_15429
# Insert of existing embedding ID: doc_15430
# Insert of existing embedding ID: doc_15431
# Insert of existing embedding ID: doc_15432
# Insert of existing embedding ID: doc_15433
# Insert of existing embedding ID: doc_15434
# Insert of existing embedding ID: doc_15435
# Insert of existing embedding ID: doc_15436
# Insert of existing embedding ID: doc_15437
# Insert of existing embedding ID: doc_15438
# Insert of existing embedding ID: doc_15439
# Insert of existing embedding ID: doc_15440
# Insert of existing embedding ID: doc_15441
# Insert of existing embedding ID: doc_15442
# Insert of existing embedding ID: doc_15443
# Insert of existing embedding ID: doc_15444
# Insert of existing embedding ID: doc_15445
# Insert of existing embedding ID: doc_15446
# Insert of existing embedding ID: doc_15447
# Insert of existing embedding ID: doc_15448
# Insert of existing embedding ID: doc_15449
# Insert of existing embedding ID: doc_15450
# Insert of existing embedding ID: doc_15451
# Insert of existing embedding ID: doc_15452
# Insert of existing embedding ID: doc_15453
# Insert of existing embedding ID: doc_15454
# Insert of existing embedding ID: doc_15455
# Insert of existing embedding ID: doc_15456
# Insert of existing embedding ID: doc_15457
# Insert of existing embedding ID: doc_15458
# Insert of existing embedding ID: doc_15459
# Insert of existing embedding ID: doc_15460
# Insert of existing embedding ID: doc_15461
# Insert of existing embedding ID: doc_15462
# Insert of existing embedding ID: doc_15463
# Insert of existing embedding ID: doc_15464
# Insert of existing embedding ID: doc_15465
# Insert of existing embedding ID: doc_15466
# Insert of existing embedding ID: doc_15467
# Insert of existing embedding ID: doc_15468
# Insert of existing embedding ID: doc_15469
# Insert of existing embedding ID: doc_15470
# Insert of existing embedding ID: doc_15471
# Insert of existing embedding ID: doc_15472
# Insert of existing embedding ID: doc_15473
# Insert of existing embedding ID: doc_15474
# Insert of existing embedding ID: doc_15475
# Insert of existing embedding ID: doc_15476
# Insert of existing embedding ID: doc_15477
# Insert of existing embedding ID: doc_15478
# Insert of existing embedding ID: doc_15479
# Insert of existing embedding ID: doc_15480
# Insert of existing embedding ID: doc_15481
# Insert of existing embedding ID: doc_15482
# Insert of existing embedding ID: doc_15483
# Insert of existing embedding ID: doc_15484
# Insert of existing embedding ID: doc_15485
# Insert of existing embedding ID: doc_15486
# Insert of existing embedding ID: doc_15487
# Insert of existing embedding ID: doc_15488
# Insert of existing embedding ID: doc_15489
# Insert of existing embedding ID: doc_15490
# Insert of existing embedding ID: doc_15491
# Insert of existing embedding ID: doc_15492
# Insert of existing embedding ID: doc_15493
# Insert of existing embedding ID: doc_15494
# Insert of existing embedding ID: doc_15495
# Insert of existing embedding ID: doc_15496
# Insert of existing embedding ID: doc_15497
# Insert of existing embedding ID: doc_15498
# Insert of existing embedding ID: doc_15499
# Add of existing embedding ID: doc_15500
# Add of existing embedding ID: doc_15501
# Add of existing embedding ID: doc_15502
# Add of existing embedding ID: doc_15503
# Add of existing embedding ID: doc_15504
# Add of existing embedding ID: doc_15505
# Add of existing embedding ID: doc_15506
# Add of existing embedding ID: doc_15507
# Add of existing embedding ID: doc_15508
# Add of existing embedding ID: doc_15509
# Add of existing embedding ID: doc_15510
# Add of existing embedding ID: doc_15511
# Add of existing embedding ID: doc_15512
# Add of existing embedding ID: doc_15513
# Add of existing embedding ID: doc_15514
# Add of existing embedding ID: doc_15515
# Add of existing embedding ID: doc_15516
# Add of existing embedding ID: doc_15517
# Add of existing embedding ID: doc_15518
# Add of existing embedding ID: doc_15519
# Add of existing embedding ID: doc_15520
# Add of existing embedding ID: doc_15521
# Add of existing embedding ID: doc_15522
# Add of existing embedding ID: doc_15523
# Add of existing embedding ID: doc_15524
# Add of existing embedding ID: doc_15525
# Add of existing embedding ID: doc_15526
# Add of existing embedding ID: doc_15527
# Add of existing embedding ID: doc_15528
# Add of existing embedding ID: doc_15529
# Add of existing embedding ID: doc_15530
# Add of existing embedding ID: doc_15531
# Add of existing embedding ID: doc_15532
# Add of existing embedding ID: doc_15533
# Add of existing embedding ID: doc_15534
# Add of existing embedding ID: doc_15535
# Add of existing embedding ID: doc_15536
# Add of existing embedding ID: doc_15537
# Add of existing embedding ID: doc_15538
# Add of existing embedding ID: doc_15539
# Add of existing embedding ID: doc_15540
# Add of existing embedding ID: doc_15541
# Add of existing embedding ID: doc_15542
# Add of existing embedding ID: doc_15543
# Add of existing embedding ID: doc_15544
# Add of existing embedding ID: doc_15545
# Add of existing embedding ID: doc_15546
# Add of existing embedding ID: doc_15547
# Add of existing embedding ID: doc_15548
# Add of existing embedding ID: doc_15549
# Add of existing embedding ID: doc_15550
# Add of existing embedding ID: doc_15551
# Add of existing embedding ID: doc_15552
# Add of existing embedding ID: doc_15553
# Add of existing embedding ID: doc_15554
# Insert of existing embedding ID: doc_15500
# Insert of existing embedding ID: doc_15501
# Insert of existing embedding ID: doc_15502
# Insert of existing embedding ID: doc_15503
# Insert of existing embedding ID: doc_15504
# Insert of existing embedding ID: doc_15505
# Insert of existing embedding ID: doc_15506
# Insert of existing embedding ID: doc_15507
# Insert of existing embedding ID: doc_15508
# Insert of existing embedding ID: doc_15509
# Insert of existing embedding ID: doc_15510
# Insert of existing embedding ID: doc_15511
# Insert of existing embedding ID: doc_15512
# Insert of existing embedding ID: doc_15513
# Insert of existing embedding ID: doc_15514
# Insert of existing embedding ID: doc_15515
# Insert of existing embedding ID: doc_15516
# Insert of existing embedding ID: doc_15517
# Insert of existing embedding ID: doc_15518
# Insert of existing embedding ID: doc_15519
# Insert of existing embedding ID: doc_15520
# Insert of existing embedding ID: doc_15521
# Insert of existing embedding ID: doc_15522
# Insert of existing embedding ID: doc_15523
# Insert of existing embedding ID: doc_15524
# Insert of existing embedding ID: doc_15525
# Insert of existing embedding ID: doc_15526
# Insert of existing embedding ID: doc_15527
# Insert of existing embedding ID: doc_15528
# Insert of existing embedding ID: doc_15529
# Insert of existing embedding ID: doc_15530
# Insert of existing embedding ID: doc_15531
# Insert of existing embedding ID: doc_15532
# Insert of existing embedding ID: doc_15533
# Insert of existing embedding ID: doc_15534
# Insert of existing embedding ID: doc_15535
# Insert of existing embedding ID: doc_15536
# Insert of existing embedding ID: doc_15537
# Insert of existing embedding ID: doc_15538
# Insert of existing embedding ID: doc_15539
# Insert of existing embedding ID: doc_15540
# Insert of existing embedding ID: doc_15541
# Insert of existing embedding ID: doc_15542
# Insert of existing embedding ID: doc_15543
# Insert of existing embedding ID: doc_15544
# Insert of existing embedding ID: doc_15545
# Insert of existing embedding ID: doc_15546
# Insert of existing embedding ID: doc_15547
# Insert of existing embedding ID: doc_15548
# Insert of existing embedding ID: doc_15549
# Insert of existing embedding ID: doc_15550
# Insert of existing embedding ID: doc_15551
# Insert of existing embedding ID: doc_15552
# Insert of existing embedding ID: doc_15553
# Insert of existing embedding ID: doc_15554
# Successfully added 15555 paragraphs to ChromaDB!

# %%
def search_query(
    query: str,
    collection: chromadb.Collection,
    model: SentenceTransformer,
    top_k: int = 3,
    threshold: float = 0.05,
    return_raw: bool = False
) -> Union[None, List[Tuple[str, float]]]:
    """
    Search for relevant documents in ChromaDB collection.
    
    Args:
        query: Search query string
        collection: ChromaDB collection to search in
        model: SentenceTransformer model instance
        top_k: Number of results to return
        threshold: Minimum similarity score (0-1) to include in results
        return_raw: If True, returns raw results instead of printing
        
    Returns:
        If return_raw is True, returns list of (document, score) tuples
        If return_raw is False, prints results and returns None
    """
    try:
        # Generate embedding for the query
        query_embedding = model.encode([query]).tolist()
        
        # Perform search in ChromaDB
        results = collection.query(
            query_embeddings=query_embedding,
            n_results=top_k,
            include=["documents", "distances", "metadatas"]
        )
        
        # Process results
        documents = results['documents'][0]
        distances = results['distances'][0]
        metadatas = results['metadata'][0] if 'metadata' in results else [{}] * len(documents)
        
        # Convert distance to similarity score (1 - distance)
        scores = [1 - dist for dist in distances]
        
        # Filter results by threshold
        filtered_results = [
            (doc, score, meta) 
            for doc, score, meta in zip(documents, scores, metadatas)
            if score >= threshold
        ]
        
        if return_raw:
            return filtered_results
        
        # Display results
        if not filtered_results:
            print("\nNo results found matching your query.")
            return None
            
        print(f"\nTop {len(filtered_results)} relevant paragraphs for query: '{query}'")
        print("-" * 80)
        
        for i, (doc, score, meta) in enumerate(filtered_results, 1):
            print(f"\n{i}. Similarity Score: {score:.4f}")
            if meta:
                print(f"Metadata: {meta}")
            print(f"Paragraph: {doc}")
            print("-" * 80)
            
    except Exception as e:
        print(f"Error performing search: {str(e)}")
        if return_raw:
            return []
    
    return None

# %%
# Initialize model and collection first
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
client = chromadb.PersistentClient(path="./chroma_storage")
collection = client.get_collection("paragraph_collection")

# %%
# Simple search
# r1 = search_query("How did relations between Greece and Turkey improve in 1999?", collection, model)

# # Search with custom parameters
# search_query(
#     "your search query",
#     collection,
#     model,
#     top_k=5,
#     threshold=0.5
# )

# Get raw results for further processing
results = search_query(
    "How many different types of iPod are currently available?",
    collection,
    embedding_model,
    return_raw=True
)

# %%
if results:
    # Process results
    for doc, score, meta in results:
        print(f"Score: {score:.4f}")
        print(f"Metadata: {meta}")
        print(f"Document: {doc}")

# %% [markdown]
# # Making the final pipeline

# %%
@dataclass
class QAResult:
    """Store QA model results with metadata"""
    answer: str
    confidence: float
    context: str
    model_name: str
    processing_time: float

class QASystem:
    def __init__(self, collection, embedding_model):
        self.collection = collection
        self.embedding_model = embedding_model
        self.models = {}
        self.initialize_models()
    
    def initialize_models(self):
        """Initialize QA model on CPU to avoid memory issues"""
        try:
            print("Loading RoBERTa model on CPU...")
            self.models['roberta'] = pipeline(
                'question-answering',
                model='deepset/roberta-base-squad2',
                device=-1  # Force CPU usage
            )
            print("Successfully loaded RoBERTa model")
        except Exception as e:
            print(f"Error loading model: {str(e)}")

    def process_search_results(
        self,
        results: List[Tuple[str, float, Dict]],
        min_score: float = 0.05
    ) -> str:
        """Process and combine search results into context."""
        # Sort results by descending score
        results = sorted(results, key=lambda x: x[1], reverse=True)

        # Filter by minimum score
        relevant_docs = [doc for doc, score, _ in results if score >= min_score]

        # Return concatenated documents or None if no relevant docs
        return " ".join(relevant_docs) if relevant_docs else ""


    def answer_question(
        self,
        question: str,
        context: str,
        model_name: str = 'roberta'
    ) -> Optional[QAResult]:
        """Generate answer using the model"""
        if not self.models:
            print("No models available.")
            return None
            
        start_time = time.time()
        
        try:
            result = self.models[model_name](
                question=question,
                context=context
            )
            
            processing_time = time.time() - start_time
            
            return QAResult(
                answer=result['answer'],
                confidence=result['score'],
                context=context,
                model_name=model_name,
                processing_time=processing_time
            )
        except Exception as e:
            print(f"Error generating answer: {str(e)}")
            return None
        
    def rephrase_answer(self, question: str, answer: str) -> str:
        """Rephrase the answer into a complete sentence."""
        if "year" in question.lower():
            return f"The year when {question[3:].strip().lower()} is {answer}."
        elif "how" in question.lower():
            return f"The way {question[4:].strip().lower()} happened is because {answer}."
        elif "why" in question.lower():
            return f"The reason {question[4:].strip().lower()} is that {answer}."
        else:
            return f"The answer to '{question}' is: {answer}."


def get_answer(
    question: str,
    search_results: List[Tuple[str, float, Dict]],
    collection,
    embedding_model,
    min_score: float = 0.05
) -> Optional[str]:
    """Complete pipeline to get answer from search results"""
    # Initialize QA system
    qa_system = QASystem(collection, embedding_model)
    
    # Process search results into context
    context = qa_system.process_search_results(search_results, min_score)
    if not context:
        print("No relevant context found with sufficient confidence score.")
        return None
    
    # Get answer
    result = qa_system.answer_question(question, context)
    if result.confidence < 0.05:
        print("Confidence score is below 0.5, consider verifying the answer.")
        return None
    
    if result:
        print("\nQuestion:", question)
        print("\nAnswer:", result.answer)
        print("Confidence:", f"{result.confidence:.4f}")
        print("Processing Time:", f"{result.processing_time:.2f}s")
        print("\nRelevant Context Used:")
        print("-" * 80)
        print(context)
        return result.answer
    return None

# %%
context = search_query(
    "in what year was the original iPod released?",
    collection,
    embedding_model,
    return_raw=True,
    top_k=3
)

# Get answer
answer = get_answer(
    "in what year was the original iPod released?",
    context,
    collection,
    embedding_model
)
# Out:
# Loading RoBERTa model on CPU...
# Device set to use cpu
# Successfully loaded RoBERTa model
#
# Question: in what year was the original iPod released?
#
# Answer: 2001
# Confidence: 0.2147
# Processing Time: 0.15s
#
# Relevant Context Used:
# --------------------------------------------------------------------------------
# In early 2001, Apple began shipping computers with CD-RW drives and emphasized the Mac's ability to play DVDs by including DVD-ROM and DVD-RAM drives as standard. Steve Jobs admitted that Apple had been "late to the party" on writable CD technology, but felt that Macs could become a "digital hub" that linked and enabled an "emerging digital lifestyle". Apple would later introduce an update to its iTunes music player software that enabled it to burn CDs, along with a controversial "Rip, Mix, Burn" advertising campaign that some felt encouraged media piracy. This accompanied the release of the iPod, Apple's first successful handheld device. Apple continued to launch products, such as the unsuccessful Power Mac G4 Cube, the education-oriented eMac, and the titanium (and later aluminium) PowerBook G4 laptop for professionals.

# %% [markdown]
# # Data Ingestion
